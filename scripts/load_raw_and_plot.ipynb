# %% [markdown]
# ### Calibration of wave gauge with temperature compensation ###

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from pathlib import Path
# import sys

plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True

# %%
# Load data

# Custom importing function
# importing my functions
# drive_d = 'D:' if sys.platform == 'win32' else '/mnt/D'  # to run on my Linux/Windows systems both
# scripts_path = Path(drive_d + '/Work/_Python3/And0K/h5toGrid/inclinometer')
# sys.path.append(str(Path(scripts_path).resolve()))
from csv_load import load_from_csv_gen
cfg_in = {'text_path':
    Path(r'd:\WorkData\_experiment\inclinometer\230425_Грузопоршневой\P\INKL_P*.TXT')
}
for i, probe_id, path_csv, df_raw in load_from_csv_gen(cfg_in):
    break
df_raw = df_raw[['P_counts', 'Temp']]
# Out:
# Raw files (6) was paths, [probe, file(s)]:
#  ('p', 'P01'): [WindowsPath('d:/WorkData/_experiment/inclinometer/230425_Грузопоршневой/P/@incl_p1.TXT'), WindowsPath('d:/WorkData/_experiment/inclinometer/230425_Грузопоршневой/P/@incl_p2.TXT'), WindowsPath('d:/WorkData/_experiment/inclinometer/230425_Грузопоршневой/P/@incl_p3-.TXT'), WindowsPath('d:/WorkData/_experiment/inclinometer/230425_Грузопоршневой/P/@incl_p3.TXT'), WindowsPath('d:/WorkData/_experiment/inclinometer/230425_Грузопоршневой/P/@incl_p4.TXT'), WindowsPath('d:/WorkData/_experiment/inclinometer/230425_Грузопоршневой/P/@incl_p5.TXT')]
# Loading 1 corrected files
# 79.9 % non-increased...
# Linearise time using reference frequency 5.0 (between holes > 2.0 s)
# .
#                                     Ax    Ay     Az   Mx   My   Mz   P_counts  \
# 2023-04-25 12:24:11+00:00          160 -2576 -13808  111  -62 -547  1849841.0
# 2023-04-25 12:24:11.200000+00:00   144 -3456 -15648  128  -65 -538  1849809.0
# 2023-04-25 12:24:11.400000+00:00   -48 -3664 -15072  110  -74 -541  1849805.0
# 2023-04-25 12:24:12+00:00         -320 -2864 -14992  108  -70 -545  1849720.0
# 2023-04-25 12:24:12.200000+00:00  -352 -2016 -15664   92  -31 -552  1849746.0
# ...                                ...   ...    ...  ...  ...  ...        ...
# 2023-04-25 18:44:40.600000+00:00     0  -480 -15728  123  147 -538  1836966.0
# 2023-04-25 18:44:40.800000+00:00     0   -64 -15904  125  149 -538  1836977.0
# 2023-04-25 18:44:41+00:00          672   128 -15808  127  152 -536  1836888.0
# 2023-04-25 18:44:41.200000+00:00  1840  -192 -16848  136  149 -533  1836927.0
# 2023-04-25 18:44:41.400000+00:00   272   736 -15872  129  141 -537  1836876.0
#
#                                    Temp  Battery
# 2023-04-25 12:24:11+00:00         21.63     5.42
# 2023-04-25 12:24:11.200000+00:00  21.63     5.42
# 2023-04-25 12:24:11.400000+00:00  21.63     5.42
# 2023-04-25 12:24:12+00:00         21.63     5.42
# 2023-04-25 12:24:12.200000+00:00  21.63     5.42
# ...                                 ...      ...
# 2023-04-25 18:44:40.600000+00:00  28.61     5.36
# 2023-04-25 18:44:40.800000+00:00  28.62     5.36
# 2023-04-25 18:44:41+00:00         28.62     5.36
# 2023-04-25 18:44:41.200000+00:00  28.62     5.36
# 2023-04-25 18:44:41.400000+00:00  28.61     5.36
#
# [113400 rows x 9 columns]

# %%
def mouse_event(event):
    print('x: {} and y: {}'.format(event.xdata, event.ydata))

fig = plt.figure()
cid = fig.canvas.mpl_connect('button_press_event', mouse_event)



df_raw.plot(figsize=(120,6), grid=True, xlabel='Time', secondary_y=['Temp'])  # = df_raw[['P_counts', 'Temp']]

# plt.plot(x, y)
# plt.show()
# click anywhere on the plot and it will show the coordinates of the points on the console
# Out:
# <AxesSubplot: xlabel='Time'>
